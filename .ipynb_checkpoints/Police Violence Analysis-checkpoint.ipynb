# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # The Data
#
# This data was retrieved from the Washington Post (via https://github.com/washingtonpost/data-police-shootings) and records several features about people shot and killed by police from 2015-2020.

# %%
data = pd.read_csv("fatal-police-shootings-data.csv")
data['date'] = pd.to_datetime(data['date'])
data['year'] = data['date'].map(lambda x: x.year)
data
# Out:
#         id                              name       date   manner_of_death  \
# 0        3                        Tim Elliot 2015-01-02              shot
# 1        4                  Lewis Lee Lembke 2015-01-02              shot
# 2        5                John Paul Quintero 2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman 2015-01-04              shot
# 4        9                 Michael Rodriguez 2015-01-04              shot
# 5       11                 Kenneth Joe Brown 2015-01-04              shot
# 6       13               Kenneth Arnold Buck 2015-01-05              shot
# 7       15                     Brock Nichols 2015-01-06              shot
# 8       16                     Autumn Steele 2015-01-06              shot
# 9       17                   Leslie Sapp III 2015-01-06              shot
# 10      19                    Patrick Wetter 2015-01-06  shot and Tasered
# 11      21                         Ron Sneed 2015-01-07              shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed 2015-01-07              shot
# 13      25            Nicholas Ryan Brickman 2015-01-07              shot
# 14      27  Omarr Julian Maximillian Jackson 2015-01-07              shot
# 15      29                     Loren Simpson 2015-01-08              shot
# 16      32               James Dudley Barker 2015-01-08              shot
# 17      36               Artago Damon Howard 2015-01-08              shot
# 18      37                      Thomas Hamby 2015-01-08              shot
# 19      38                     Jimmy Foreman 2015-01-09              shot
# 20     325                     Andy Martinez 2015-01-09              shot
# 21      42                       Tommy Smith 2015-01-11              shot
# 22      43                    Brian  Barbosa 2015-01-11              shot
# 23      45                 Salvador Figueroa 2015-01-11  shot and Tasered
# 24      46               John Edward O'Keefe 2015-01-13              shot
# 25      48                 Richard McClendon 2015-01-13              shot
# 26      49                     Marcus Golden 2015-01-14              shot
# 27      50                    Michael Goebel 2015-01-14              shot
# 28      51                      Mario Jordan 2015-01-14              shot
# 29      52                  Talbot Schroeder 2015-01-14              shot
# ...    ...                               ...        ...               ...
# 5330  5820          Wilbon Cleveland Woodard 2020-05-19              shot
# 5331  5824                        Tyler Hays 2020-05-19              shot
# 5332  5816                             TK TK 2020-05-19  shot and Tasered
# 5333  5815                             TK TK 2020-05-20              shot
# 5334  5840        Bernardo Palacios-Carbajal 2020-05-23              shot
# 5335  5836                    Michael Snyder 2020-05-24              shot
# 5336  5837                    Gary P. Dorton 2020-05-25              shot
# 5337  5839                             TK TK 2020-05-25              shot
# 5338  5841                      Dion Johnson 2020-05-25              shot
# 5339  5854                Richard Councilman 2020-05-26              shot
# 5340  5857              Jason Jesse Gallegos 2020-05-26              shot
# 5341  5860                   Kenneth Bennett 2020-05-26              shot
# 5342  5862                             TK TK 2020-05-26              shot
# 5343  5861                John Allen Dunaway 2020-05-26  shot and Tasered
# 5344  5843                       Tony McDade 2020-05-27              shot
# 5345  5847                    Joshua Blessed 2020-05-27              shot
# 5346  5856                    Rommel Mendoza 2020-05-27              shot
# 5347  5858                             TK TK 2020-05-27              shot
# 5348  5859                   Alexander Scott 2020-05-27              shot
# 5349  5846                     Modesto Reyes 2020-05-27  shot and Tasered
# 5350  5853             John Benedict Coleman 2020-05-28              shot
# 5351  5855                             TK TK 2020-05-28              shot
# 5352  5851                             TK TK 2020-05-28  shot and Tasered
# 5353  5844             Heba Momtaz Al-Azhari 2020-05-29              shot
# 5354  5845                             TK TK 2020-05-29              shot
# 5355  5848                             TK TK 2020-05-29              shot
# 5356  5849                             TK TK 2020-05-29              shot
# 5357  5850                             TK TK 2020-05-29              shot
# 5358  5852                             TK TK 2020-05-31              shot
# 5359  5842                             TK TK 2020-06-01              shot
#
#                armed   age gender race               city state  \
# 0                gun  53.0      M    A            Shelton    WA
# 1                gun  47.0      M    W              Aloha    OR
# 2            unarmed  23.0      M    H            Wichita    KS
# 3         toy weapon  32.0      M    W      San Francisco    CA
# 4           nail gun  39.0      M    H              Evans    CO
# 5                gun  18.0      M    W            Guthrie    OK
# 6                gun  22.0      M    H           Chandler    AZ
# 7                gun  35.0      M    W            Assaria    KS
# 8            unarmed  34.0      F    W         Burlington    IA
# 9         toy weapon  47.0      M    B          Knoxville    PA
# 10             knife  25.0      M    W           Stockton    CA
# 11               gun  31.0      M    B           Freeport    TX
# 12             knife  41.0      M    B           Columbus    OH
# 13               gun  30.0      M    W         Des Moines    IA
# 14               gun  37.0      M    B        New Orleans    LA
# 15               NaN  28.0      M    W            Huntley    MT
# 16            shovel  42.0      M    W     Salt Lake City    UT
# 17           unarmed  36.0      M    B             Strong    AR
# 18               gun  49.0      M    W           Syracuse    UT
# 19               gun  71.0      M    W            England    AR
# 20               gun  33.0      M    H            El Paso    TX
# 21               gun  39.0      M    W             Arcola    IL
# 22               gun  23.0      M    H         South Gate    CA
# 23               gun  29.0      M    H    North Las Vegas    NV
# 24               gun  34.0      M    W        Albuquerque    NM
# 25             knife  43.0      M    W         Jourdanton    TX
# 26               NaN  24.0      M    B           St. Paul    MN
# 27               NaN  29.0      M    W    Franklin County    MO
# 28               gun  34.0      M    B         Chesapeake    VA
# 29             knife  75.0      M    W         Old Bridge    NJ
# ...              ...   ...    ...  ...                ...   ...
# 5330  unknown weapon  69.0      M    W        Tallahassee    FL
# 5331         unarmed  29.0      M    W         Sale Creek    TN
# 5332           knife   NaN      M  NaN            Seattle    WA
# 5333             gun   NaN      M  NaN              Viera    FL
# 5334             gun  22.0      M    H     Salt Lake City    UT
# 5335             gun  44.0      M  NaN          Bulls Gap    TN
# 5336           knife  43.0      M  NaN       Jonesborough    TN
# 5337             gun  38.0      M    H            Houston    TX
# 5338    undetermined  28.0      M  NaN            Phoenix    AZ
# 5339             gun   NaN      M  NaN          Jamestown    CA
# 5340             gun  37.0      M  NaN            Lansing    MI
# 5341      toy weapon  61.0      M  NaN            Manlius    NY
# 5342         unarmed   NaN      M  NaN    North Las Vegas    NV
# 5343         unarmed  61.0      M  NaN       Jacksonville    FL
# 5344             gun  38.0      M    B        Tallahassee    FL
# 5345             gun  58.0      M    W            Geneseo    NY
# 5346           sword  50.0      M  NaN        Los Angeles    CA
# 5347           knife   NaN      M  NaN          Fullerton    CA
# 5348           knife  30.0      M  NaN          Wilburton    OK
# 5349             gun  35.0      M    B   Jefferson Parish    LA
# 5350             gun  53.0      M  NaN              Ogden    UT
# 5351    undetermined   NaN      M  NaN         Centennial    CO
# 5352           knife   NaN      M  NaN  Washington County    OR
# 5353           knife  22.0      F    A     Temple Terrace    FL
# 5354             gun   NaN      M    W          Lancaster    CA
# 5355             gun  32.0      M    A          San Diego    CA
# 5356           knife   NaN      M  NaN       Philadelphia    PA
# 5357             gun   NaN      M  NaN         Snellville    GA
# 5358    undetermined   NaN      M    W           Portland    OR
# 5359    undetermined   NaN      M  NaN         Louisville    KY
#
#       signs_of_mental_illness  threat_level         flee  body_camera  year
# 0                        True        attack  Not fleeing        False  2015
# 1                       False        attack  Not fleeing        False  2015
# 2                       False         other  Not fleeing        False  2015
# 3                        True        attack  Not fleeing        False  2015
# 4                       False        attack  Not fleeing        False  2015
# 5                       False        attack  Not fleeing        False  2015
# 6                       False        attack          Car        False  2015
# 7                       False        attack  Not fleeing        False  2015
# 8                       False         other  Not fleeing         True  2015
# 9                       False        attack  Not fleeing        False  2015
# 10                      False        attack  Not fleeing        False  2015
# 11                      False        attack  Not fleeing        False  2015
# 12                       True         other  Not fleeing        False  2015
# 13                      False        attack          Car        False  2015
# 14                      False        attack         Foot         True  2015
# 15                      False  undetermined  Not fleeing        False  2015
# 16                      False        attack  Not fleeing         True  2015
# 17                      False        attack  Not fleeing        False  2015
# 18                      False        attack  Not fleeing         True  2015
# 19                      False        attack  Not fleeing        False  2015
# 20                      False        attack  Not fleeing        False  2015
# 21                       True        attack  Not fleeing        False  2015
# 22                      False        attack  Not fleeing        False  2015
# 23                      False        attack         Foot        False  2015
# 24                      False        attack         Foot         True  2015
# 25                       True         other  Not fleeing        False  2015
# 26                      False        attack  Not fleeing        False  2015
# 27                      False        attack  Not fleeing        False  2015
# 28                       True        attack  Not fleeing        False  2015
# 29                      False        attack  Not fleeing        False  2015
# ...                       ...           ...          ...          ...   ...
# 5330                    False         other  Not fleeing        False  2020
# 5331                    False        attack  Not fleeing        False  2020
# 5332                    False  undetermined         Foot         True  2020
# 5333                     True        attack  Not fleeing        False  2020
# 5334                    False         other         Foot         True  2020
# 5335                     True        attack         Foot        False  2020
# 5336                     True        attack  Not fleeing        False  2020
# 5337                    False        attack  Not fleeing        False  2020
# 5338                    False  undetermined  Not fleeing        False  2020
# 5339                     True         other  Not fleeing        False  2020
# 5340                     True        attack  Not fleeing         True  2020
# 5341                     True  undetermined  Not fleeing        False  2020
# 5342                    False        attack  Not fleeing        False  2020
# 5343                    False         other         Foot        False  2020
# 5344                    False         other  Not fleeing        False  2020
# 5345                    False        attack          Car        False  2020
# 5346                    False  undetermined          NaN        False  2020
# 5347                    False        attack  Not fleeing        False  2020
# 5348                    False        attack  Not fleeing        False  2020
# 5349                    False        attack        Other         True  2020
# 5350                    False        attack  Not fleeing        False  2020
# 5351                    False         other          Car        False  2020
# 5352                    False         other  Not fleeing         True  2020
# 5353                     True         other  Not fleeing        False  2020
# 5354                    False         other          NaN        False  2020
# 5355                    False        attack          NaN        False  2020
# 5356                    False         other  Not fleeing        False  2020
# 5357                    False        attack          Car        False  2020
# 5358                    False  undetermined          NaN        False  2020
# 5359                    False  undetermined          NaN        False  2020
#
# [5360 rows x 15 columns]

# %% [markdown]
# ## The number of people shot and killed by police has been consistent from 2015 through 2019

# %%
data_by_year = data.groupby(['year']).count()
fig, ax = plt.subplots()
ax.set_xlabel("Year")
ax.set_ylabel("Number of People")
plt.bar(x=data_by_year.index, height=data_by_year['id'])
plt.title("Number of People Shot and Killed by Police")
plt.show()

# %% [markdown]
# # Number of People Killed by Police from 2015-2020
#
# Since 2015, over 5000 people have been killed by the police in various circumstances. It appears that white people tend to be killed by cops more often than any other race. However, there is more to this story.

# %%
data_by_race = data.groupby(['race']).count().sort_values(by=['id'], ascending=False)
fig, ax = plt.subplots()
ax.set_xlabel("Race")
ax.set_ylabel("Number of People")
plt.bar(x=['White', 'Black', 'Hispanic', 'Asian', 'Native', 'Other'], height=data_by_race['id'])
plt.title("Number of People Shot and Killed by Police")
plt.savefig('number.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # United States Demographics (2019 Estimates)
#
# According to census.gov (via https://www.census.gov/quickfacts/fact/table/US/PST045219), with a total of 328,239,523 people living in the US,
#
# - White people make up 76.5% of the US population (251,103,235 people)
# - Hispanic or Latino people make up 18.3% of the population (60,067,833 people)
# - Black people make up 13.4% of the US population (43,984,096 people)
# - Asian people make up 5.9% of the US population (19,366,132 people)
# - Native American people make up 1.5% of the US population (4,923,592 people)

# %%
data_by_race = data_by_race[['name', 'id']]
data_by_race = data_by_race[data_by_race.index != 'O']
race_props = pd.Series(data=[19366132, 43984096, 60067833, 4923592,251103235], index=['A', 'B', 'H', 'N', 'W'])
data_by_race['id'] = data_by_race['id'] / race_props
data_by_race = data_by_race.rename(columns={'name':'count', 'id':'proportion'})
data_by_race = data_by_race.sort_values(by=['proportion'], ascending=False)
data_by_race
# Out:
#       count  proportion
# race
# B      1260    0.000029
# N        77    0.000016
# H       887    0.000015
# W      2410    0.000010
# A        93    0.000005

# %% [markdown]
# # Minorities are Killed by Police at a Higher Rate than White People
#
# The previous figure showed that more white people have been killed over the past 5 years than any other race, a statistic that can understandably skew peoples' perspectives. However, when you take into account that the United States has many more white people (76.5% of the population), it makes more sense to look at proportions. **Black people are killed at a rate 3 times higher than white people.** This is indicative of a phenomenon larger than just the law enforcement system itself. We need to look at *why* these individuals are being killed.

# %%
fig, ax = plt.subplots()
ax.set_xlabel("Race")
ax.set_ylabel("Proportion")
plt.bar(x=['Black', 'Native', 'Hispanic', 'White', 'Asian'], height=data_by_race['proportion'])
plt.title("Proportion of People Killed by Police")
plt.savefig('prop.png', bbox_inches='tight')
plt.show()

# %%
num_black_unarmed_prop = len(data.loc[(data['race']=='B') & (data['armed']=='unarmed')])/1260
num_white_unarmed_prop = len(data.loc[(data['race']=='W') & (data['armed']=='unarmed')])/2410
num_native_unarmed_prop = len(data.loc[(data['race']=='N') & (data['armed']=='unarmed')])/77
num_hispanic_unarmed_prop = len(data.loc[(data['race']=='H') & (data['armed']=='unarmed')])/887
num_asian_unarmed_prop = len(data.loc[(data['race']=='A') & (data['armed']=='unarmed')])/93
unarmed_props = [num_black_unarmed_prop, num_hispanic_unarmed_prop, num_white_unarmed_prop, num_asian_unarmed_prop, num_native_unarmed_prop]

# %% [markdown]
# ## Of all fatal shootings by police by race, unarmed black people make up the highest proportion.
#
# When we look at the shootings by race, we see that almost 10% of black people killed by police were unarmed. This figure is over 50% greater than the same proportion for white people.

# %%
fig, ax = plt.subplots()
ax.set_xlabel("Race")
ax.set_ylabel("Proportion")
plt.bar(x=['Black', 'Hispanic', 'White', 'Asian', 'Native'], height=unarmed_props)
plt.title("Proportion of Unarmed People Killed by Police")
plt.savefig('unarmed.png', bbox_inches='tight')
plt.show()

# %%
num_black_unarmed_prop/num_white_unarmed_prop
# Out:
# 1.50484360410831
